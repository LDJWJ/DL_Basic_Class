# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
import re
from selenium import webdriver

# %%
url = "https://www.youtube.com/c/SKtelecom/videos"

# %%
driver = webdriver.Chrome('./chromedriver_85.exe')
driver.get(url)

# %%
page = driver.page_source
soup = BeautifulSoup(page, 'html.parser')
soup.title
# Out:
# <title>SK telecom - YouTube</title>

# %%
# 하나의 제목 가져오기
soup.find("a", class_="yt-simple-endpoint style-scope ytd-grid-video-renderer").text
# Out:
# '긴급 재난 문자 수신 설정 방법'

# %%
all_title = soup.find_all("a", class_="yt-simple-endpoint style-scope ytd-grid-video-renderer")

title = []
for one in all_title:
    # print(one.text)
    title.append(one.text)
title
# Out:
# ['긴급 재난 문자 수신 설정 방법',
#  '[SK텔레콤 5G] 누구든 보고 어디서든 느낄 수 있도록 ‘창덕ARirang at Home’',
#  '행복을 드리는 SK텔레콤 고객센터 김은혜입니다',
#  '[SKT x 최태성] 언택트 시대 & 4차 산업혁명, 기업의 미래는?',
#  'T전화 활용하기_T114 업체 정보 등록 방법',
#  '임요환과 G식백과가 푹~ 빠진 이것은 무엇..!? 🎮SKT 5GX 클라우드 게임🎮',
#  '[SKT IMPACTUPS] 스마프',
#  '[SKT IMPACTUPS] 칸필터',
#  '[SK텔레콤] V 컬러링, 김연아의 힐링 편',
#  '[SK텔레콤] V 컬러링, 김연아의 구름이링 편',
#  '[SK텔레콤] V 컬러링, 김연아의 전화위복링 편',
#  '[SK텔레콤] V 컬러링, 김연아의 매너링 편',
#  '[SK텔레콤] V 컬러링, 김연아의 힐링 콘텐츠 편',
#  '♡나와 소중한 사람들을 위해 이번 추석은 여기서 만나요♡ (feat.미더스(MeetUs))',
#  '[SKT IMPACTUPS] 유메인',
#  '[SKT IMPACTUPS] 수퍼빈',
#  '[SKT IMPACTUPS] 에이런',
#  '[SK텔레콤] V 컬러링, 김연아의 매너링 편',
#  '[SK텔레콤] V 컬러링, 김연아의 힐링 편',
#  '[SKT IMPACTUPS] atlab',
#  '[SKT IMPACTUPS] H2K',
#  '[SKT IMPACTUPS] 룩시드랩스',
#  '[Like a Local] Only at SK Telecom!',
#  '[SKT IMPACTUPS] 닥터스팹',
#  '[SKT IMPACTUPS] 리그넘',
#  '[SKT IMPACTUPS] 종합편',
#  '🤳🏻이제 컬러링을 듣는게 아니라 본대..!!! 👀 (Feat.  V컬러링 체험기)',
#  '[SK텔레콤] V 컬러링, 서장훈의 추석링 편',
#  '[SK텔레콤] V 컬러링, 서장훈의 잔소링 편',
#  '[SK텔레콤] V 컬러링, 서장훈의 응원링 편',
#  '[SK텔레콤] V 컬러링, 서장훈의 약올링 편',
#  '[SK텔레콤] V컬러링, 서장훈의 추석링 편',
#  '[SK텔레콤] V컬러링, 서장훈의 잔소링 편',
#  '[SK텔레콤] V컬러링, 서장훈의 응원링 편',
#  '[SK텔레콤] V컬러링, 서장훈의 약올링 편',
#  '[T다이렉트샵] 최신 수사 기법 Z대로 보여드림 l 위대한 탐정 Z',
#  '[선배 박람회] 내가 찾던 선배와의 랜선 만남🤳–‘직업 선배’편💌',
#  '[선배 박람회] 내가 찾던 선배와의 랜선 만남🤳- ‘인생 선배’편💌',
#  "[SK텔레콤] 페이커의 '창덕ARirang at Home' 랜선 여행기",
#  '[SK텔레콤] V컬러링, 손흥민 편',
#  '갤럭시 Z에 대한 모든 것을 ZZㅔ대로 참견해준 찐참견러들의 유쾌한 갤럭시 Z-라이브!',
#  'SK텔레콤 5GX와 함께하는 24시간 지구연결 프로젝트에 참여해보세요!',
#  '내가 알던 콘솔 게임 맞아..!?🧐 XBOX MVP🎮 유정군이 알려주는 SKT 5GX 클라우드 게임 A to Z💨',
#  '[Like a Local] MIRI Part 2',
#  '[🔴LIVE] ZZㅔ대로 참견해드립니다! 사전예약 초청 Galaxy Z-LIVE #찐들의참견',
#  "🔑'PASS(패스)’로 일상의 소리가 바뀌기 시작했다?!👀곧 잃어버릴 소리를 찾아서~🔐",
#  'T월드 앱 활용하기_T가족모아데이터 공유 방법',
#  'T전화 유용한 기능_활용편(그룹통화 & 데이터 선물하기)',
#  '행복을 드리는 SK텔레콤 고객센터 박유진입니다',
#  "[SK텔레콤] 손흥민도 감탄한 '창덕ARirang at Home' 체험기",
#  '데이터는 거짓말 안해요~🤷🏻\u200d♂📱‘T맵 미식로드’로 알아보는 찐맛집🍽(feat. 디지털 문화 심리학자)',
#  '[SK텔레콤 5G] 송가인-김연아, 세계최초 드라이브 스루 개통행사에 떴다? SKT 5GX Galaxy Note20 런칭 쇼케이스',
#  'SKT 5GX 클라우드 게임, 갤럭시 노트20로 Xbox 게임을 더 생생하게',
#  '[SK텔레콤 5G] SKT 5GX 클라우드 게임으로, Xbox 게임을 마음껏',
#  '[SK텔레콤 5G] SKT 5GX로, Xbox 게임을 내 손안에',
#  '[SK텔레콤] NUGU opal (누구 오팔) 금영노래방, 두뇌 체조, 종교 Play 사용 방법',
#  '가족과 함께라면 커지는 할인 혜택, 온가족 플랜',
#  '내 손안의 TV, 모바일 B tv 앱 (셋톱 박스와 연결하기)',
#  '[SK텔레콤] NUGU opal (누구 오팔) 투약알림 설정 방법',
#  '⭐️최초공개⭐️ 고요한 모빌리티🚕 타봤니?😎🤔',
#  '[Like a Local] Bring Your Own Device',
#  '[SK텔레콤] 5천만 명의 매일을 위한 5천만 개의 SK텔레콤으로',
#  '[SK텔레콤] NUGU opal (누구 오팔) 일정알림 설정 방법',
#  '[SK텔레콤] NUGU opal (누구 오팔) 이용통계 사용 방법',
#  '[SK텔레콤 5G] SKT 5GX로 갤럭시 노트20 구매하고 독보적 혜택을 누려라!',
#  '[SK텔레콤] NUGU opal (누구 오팔) 생활알림 설정 방법',
#  '[SK텔레콤] 행복한 폰 쇼핑, T다이렉트샵 (갤럭시 노트20 편)',
#  '[SK텔레콤] 행복한 폰 쇼핑, T다이렉트샵',
#  '[SK텔레콤 5G] SKT 5GX 클라우드 게임으로, Xbox 게임을 언제 어디서나.',
#  '(▩귀여움 주의▩) 3D 홀로그램을 직접 만들어 보았다! (feat.점프 스튜디오)',
#  '야, 너두 해외로 여름휴가 갈 수 있어!언택트 랜선 여행, 여행 ON기분✈',
#  '[NUGU opal] 송가인 오팔쏭🎵 3탄 투약알림! 보석 같은 친구~ 누구 오팔이어라~',
#  '[NUGU opal] 송가인 오팔쏭🎵 2탄 금영노래방! 가인이어라~ 오팔이어라~',
#  '[NUGU opal] 송가인 오팔쏭🎵 1탄 두뇌체조! 치매 걱정 없애~ 오팔이어라~',
#  '[SK텔레콤 5G] 모든 사람이 무엇이든 볼 수 있고 어디든 갈 수 있도록 ‘창덕ARirang’',
#  '[선공개] 송가인 opal쏭 100만뷰 공약?',
#  '[SK텔레콤] NUGU opal (누구 오팔) 디바이스 연결 방법',
#  '[Like a Local] How to Read Your Phone Bills',
#  '[SK텔레콤] NUGU opal (누구 오팔) 이용권 구매/등록 방법',
#  '행복을 드리는 SK텔레콤 고객센터 박영식입니다',
#  '나 어제 파리 가서 쇼핑했잖아🇫🇷 언택트 랜선 여행, 여행ON기분✈',
#  '👊마인크래프트가 왜 거기서 나와!?👊우리 아이 시간 순삭 코딩 체험기👨🏻\u200d💻🎶',
#  '[Like a Local] A New Way to Pay, ‘MIRI’',
#  '0해야 누릴 수 있는 특권! 0한동 앱 이용하기',
#  '[실험 카메라] 휴대폰 속 개인정보🤳, 완벽한 삭제가 가능할까?🧐 (feat. 공돌이 용달)',
#  '[☞범인은 이 안에 있어!☜] AI가 영상 속 침입자를 찾는다고?',
#  '지진을 이 센서로 감지한다고?🔎지진 관측, 어디까지 알고 있니..!?⚡📡',
#  '위드캠페인에 이렇게 참여하세요 (feat.사랑의돌봄)',
#  '휴대폰 분실 보상 접수하기 -분실파손보험 가입 고객',
#  '[SKT 고객센터] B tv 리모컨 장애 해결 가이드',
#  "[◐T.um x Bewhy◑] 비와이X심바 자와디의 '힘' 뮤비 촬영 장소는 어디?!",
#  '[with캠페인] 방과 후 혼자 지내는 아이들과 함께 해주세요',
#  '휴대폰 파손 보상 접수하기',
#  '[PASS by SKT] PASS로 패스하면 뭐가 좋을까?',
#  '[PASS by SKT] 운전면허증이 휴대폰 바코드가 된다?',
#  '야 너두 할 수 있어..!💉🩸 핵쉬운 헌혈법 대공개🥳',
#  '집중👀초크들이 알랴드림📣“인택트 면접이란 말이야…” (feat. 상반기 채용)',
#  '💥LoL 장인들이 한자리에 모이면..!?💥 대유잼 LCK 썸머 프로필 촬영 현장 비하인드!!👀',
#  '행복을 드리는 SK텔레콤 고객센터 김상휘입니다',
#  '[SK텔레콤] 2020 SKT 행복 인사이트(~7/13)',
#  '[SK텔레콤] 언택트 시대, 우리집 지킴이 캡스홈',
#  '[SK텔레콤] ADT캡스가 지키는 우리집, 캡스홈',
#  "'빛정수'와 함께 갤럭시A퀀텀 열어볼까요..? 💗",
#  '슬기로운 보안생활을 위한 꿀팁 공개🍯 결론은 ‘갤럭시 A 퀀텀’🤳(feat. 프로 보안러)',
#  '알아서 척척!!🤖 열일하는 SKT 방역로봇을 소개합니다~!',
#  '[SK텔레콤 T다이렉트샵] 갤럭시 A 퀀텀, 오늘 사면, 오늘 도착!',
#  '[SK텔레콤 T다이렉트샵] 갤럭시 A 퀀텀 구매부터 배송까지 친절상담!',
#  '[SK텔레콤 T다이렉트샵] 갤럭시 A 퀀텀 살 때, 쓰던 폰 오늘보상!',
#  '[SK텔레콤] 새학기 ZEM으로 안심등교하세요~',
#  '[SK텔레콤 T다이렉트샵] 갤럭시 A 퀀텀을 다이렉트 플랜으로 구매하세요.',
#  '0들이 바라던 iPhone SE를 SK텔레콤만의 특별한 혜택으로',
#  '보안의 클라쓰가 다르다..! 퀀.텀.키.퍼(feat. 갤럭시A퀀텀 체험존)',
#  '[SK텔레콤 5G] 내 결제지문 노출이 걱정될 때, “이것” 만 기억하세요!',
#  '[SK텔레콤 5G] 내 T ID 자꾸 넘보는 동생 퇴치법을 공개합니다!',
#  '극과 극 집콕 랜선생활! 언택트 시대 그들이 사는법 (feat. 집돌이 VS 밖돌이)',
#  '스피드 중계기를 소개합니다',
#  '언택트 시대🤳 SKT 온라인 기자간담회 현장을 가다! 👨🏻\u200d💻🎥',
#  '[SK텔레콤 5G] 내 소중한 증명서, 철통같이 지키고 싶다면?',
#  '사진만 찍으면 진짜와 똑같은 복제 가상 공간을 만들 수 있다고?',
#  '[SK텔레콤 5G] 갤럭시 퀀텀, 안심을 심다',
#  '집에서 즐기는 똑똑한 음악놀이 B tv 플레이송스 홈',
#  '[SK텔레콤 5G] 갤럭시 퀀텀, 세계 최초 양자 보안 5G 스마트폰',
#  '[SK텔레콤 5G] 세계 최초 양자 보안 5G 스마트폰, 갤럭시 퀀텀을 소개합니다',
#  '[사장님 안심경영팩] SKT가 소상공인 2만명에게 쏩니다🙆🏻\u200d♂👋🏼',
#  '[SK Telecom] Artificial Intelligence Care for Seniors Serves as Social Safety Net in Korea',
#  '국민 센터 아빠 매튜도 놀란 ‘이것’의 정체는? ADT캡스 ‘캡스홈’! 안전을 선물하다 (feat. 매튜 다우마)',
#  '행복을 드리는 SK텔레콤 고객센터 양이슬입니다',
#  '모르면 손해! T map만의 특별한 혜택',
#  '청정력 뿜뿜!! Tworld 안심하고 방문하세요(Feat. Tworld 보신각점👦🏻👩🏻🧑🏻👨🏻)',
#  'SK텔레콤 통신요금 셀프 납부하기',
#  '최대 100명까지 한 통화에, 일하는 방식을 바꾸다 [T그룹통화]',
#  'SK텔레콤 Giga Wi-Fi 알아보기',
#  'AI가 관상까지 본다!?🤭 영상 얼굴인식의 모든것‼',
#  '최대 100명까지 한 통화에, 일하는 방식을 바꾸다 [T그룹통화]',
#  '[SK텔레콤 2020 상반기 T-Career Cast] 수시채용 직무소개',
#  '[SK텔레콤 2020 상반기 T-Career Cast] 정기채용 직무소개',
#  '[SKT 고객센터] 나만의 부가서비스 팩! 스마트콜Pick',
#  '[SK텔레콤 2020 상반기 T-Career Cast] Junior Talent 채용 전형소개',
#  '재택근무 꿀팁 모음🛏 출근 1분컷! 집에서 일하는 노하우',
#  "이것이 바로 K-배송이다👍 들어는 봤니? 'T다이렉트샵'!! 🛵 (feat. 외국인코리아)",
#  '공대생들이라면 줍줍하세효~🙈✨AI Fellowship 2기 모집✨',
#  '(※특.별.편.성) 홍보맨 태구의 사소한 궁금증 (feat. 채널 바꾸는 시간)',
#  '합격자피셜 꿀팁!  1,2년차의  REAL 입사 노하우 대방출',
#  '이런 출근 처음이야.. 👏🏻방 문 열고 출근하는 끄뇽이의 재택근무🛏🎶',
#  "중고 휴대폰을 ATM으로 바로 파는 스마트한 거래 '민팃'",
#  '갤럭시 S20을 SKT에서 사야하는 6가지 이유! ‘아우라 블루’ 리뷰부터 구매 꿀팁까지 대방출?! (feat. 오라잇 스튜디오)',
#  '사번과 자리도 있는 AI 동료와 일해봤어요?',
#  '[SK텔레콤 5G] 갤럭시 S20+ 아우라 블루, 오직 SK텔레콤에서만',
#  '옐언니와 함께하는 ZEM있는 새학기',
#  'T월드 다이렉트에서 구매한 기기 받는 방법',
#  '[NUGU x ODG] 10살로 돌아간다면, 누구랑 대화를 해보고 싶으신가요?',
#  '[0 FESTA] 20살을 앞둔 0들과 국내 최정상 아티스트들의 만남!',
#  '[SK텔레콤] 기술은 언제나 당신을 향합니다, T스마트폰 교실',
#  '고객센터 114, 보이는 ARS로 쉽고 빠르게',
#  '[SK텔레콤] Welcome to CES 2020, 5G 시대를 선도하는 SKT 부스의 이모저모!',
#  '[SK텔레콤] Welcome to CES 2020, 신기방기템을 소개합니다!',
#  '[SK텔레콤] Welcome to CES 2020, SKT부스를 가다!',
#  '[SK텔레콤x긱블] 아빠를 위한 아주 특별한 크리스마스 선물',
#  '[SK텔레콤 5G] 이제 Boost Park가 대세! Boost Park 대전 둔산 여행기 (feat. 상황극 남매)',
#  '[동물 없는 동물원 - 북극곰편] 이제, 만날 수 없던 친구와 다시 마주합니다',
#  '[SK텔레콤] T Honors 편',
#  '[SK텔레콤] 기술은 언제나 당신을 향합니다, 손누리링',
#  '법인폰 개인인증 서비스 신청_실제 사용자 편',
#  '[SK텔레콤 5G] 5GX 뮤직 멀티뷰, 파워풀한 댄스의 비밀',
#  '[SK텔레콤 5G] 5GX 뮤직 멀티뷰, 환상적인 연주의 비밀',
#  '[SK텔레콤] 무선인터넷 도시, "무인도"로 떠나보세요',
#  'SK텔레콤 휴대폰 나의 가입 정보 확인',
#  '[SK텔레콤] T월드는 다 계획이 있구나! | 기생충 패러디편',
#  '[SK텔레콤 5G] 가상과 현실을 넘나들며 함께하는 즐거움! 버추얼 소셜 월드',
#  '휴대폰 분실, 파손으로 대체할 폰이 필요할 때',
#  '[SK Telecom 5G] Leading towards a brighter future, 5GX, SK Telecom',
#  '해외에서 baro 만나!',
#  '[SK텔레콤 5G] Oculus Go 시작하기 편',
#  '[SK텔레콤 5G] Oculus Go 관리하기 편',
#  'T아이디 찾기 / 비밀번호 재설정',
#  '[SK텔레콤] 초시대의 갤럭시 생활, Galaxy A80',
#  '[SK텔레콤] 수능끝나고 0페스티벌! 2019 수고0페',
#  '레드커넥트를 만나 ‘행복한 헌혈’을 하다',
#  '[SK텔레콤] 아이린의 달콤한 목소리로 아침을 맞이할 수 있다면?  NUGU 셀럽 알람_아이린편',
#  '나만 몰랐던 T map 운전습관',
#  '[SK텔레콤] Galaxy A80 사전예약 편',
#  '[SK텔레콤] 민속마을 선비들의 티움모바일 유람기 (feat. 남계서원)',
#  '[SK텔레콤] 코딩학습과 AI를 한 번에! 알버트AI_NUGU편',
#  '[SK텔레콤] 코딩학습과 AI를 한 번에! 알버트AI_코딩편',
#  "[SK텔레콤] iPhone 11과 0이 만났다! iPhone 11 론칭 쇼케이스 'District 0'에 가다",
#  '[SK텔레콤 5G] 완전깜놀! 그들이 나타났다!! ‘SKT T1 팬미팅 현장’',
#  '[SK텔레콤] 세상 모든 0을 위한 iPhone 11 Pro, 망원 카메라의 화각처럼 혜택의 집중, SK텔레콤만의 AppleCare',
#  '[SK텔레콤] 세상 모든 0을 위한 iPhone 11 Pro, 울트라 와이드 카메라의 화각처럼 넓은 혜택, SK텔레콤만의 AppleCare',
#  'B tv AI 셋톱박스 활용하기',
#  '휴대폰 분실 대처 요령',
#  '지금 당신의 음악, FLO',
#  '내 손 안의 안전한 요금안내서, 빌레터',
#  '간편한 휴대폰 번호 변경',
#  'B tv 시청 장애 해결 가이드',
#  '인터넷 접속 장애 해결 가이드',
#  'SK텔레콤 AI 상담사 채티 (챗봇)',
#  '스미싱/스팸 차단 방법',
#  '데이터 로밍 차단, 2분이면 충분!',
#  '[SK텔레콤]세상 모든 0을 위한 iPhone 11 Pro, SK텔레콤만의 AppleCare와 함께 더 새로워지다',
#  '[SK텔레콤] 핫한 골목에서 할인 받고 착한 소비도 할 수 있다면? ‘다 함께 동네 한 바퀴’ (feat. 김민경, 밤비걸)',
#  '[SK텔레콤] 폰 바꿀 땐 티다 오늘보상',
#  '[SK텔레콤 5G] 초시대 부팍 생활, 재미와 혜택이 부스트 되는 부팍가서 즐겨보자!',
#  '[SK텔레콤]세상 모든 0을 위한 iPhone 11 Pro',
#  '[SK텔레콤]세상 모든 0을 위한 iPhone 11 Pro',
#  '[SK텔레콤] SK텔레콤 직원들이 행복하게 일하는 비결은? 초크초크한 리뷰',
#  '[SK텔레콤 5G] 5G와 VR이 만나면 이런 것까지 가능하다? KOREA VR FESTIVAL 2019 체험기! 초크초크한 리뷰',
#  '[SK텔레콤] 초시대 잼있는 생활, ZEM, APP 기능 안내',
#  '[SK텔레콤] 초시대 잼있는 생활, ZEM, 키즈 서비스 안내',
#  '[SK텔레콤] 초시대 잼있는 생활, ZEM',
#  '[SK텔레콤 5G] SKT 5GX AR 동물원 메이킹 스토리',
#  '[SK텔레콤]초시대 영통생활, T전화 콜라',
#  '[5G로 떠나는 0순위여행 | EP.10] 끝나지 않은 안테나의 응원곡, 우리 모두의 0순위여행',
#  '[SK텔레콤 5G] 5G와 함께라면 스마트폰으로 XBOX 게임이 가능하다? SKT와 MS가 함께하는 5G 클라우드 게임 시대!',
#  '[SK텔레콤] 가족을 지킵니다! 손목시계 밴드형 배회감지기 SKT Smart 지킴이',
#  '[SK텔레콤 5G] 최애 멤버만 골라보는 SKT 뮤직 멀티뷰',
#  '0을 위한 시대 (0teen데이터슈퍼패스 / 데이터스테이션)',
#  '0을 위한 시대 (0혜택 / 0캠퍼스)',
#  '[5G로 떠나는 0순위여행 | EP.9] 안테나가 전하는 0을 위한 응원가, 취향존중 라이브 앨범 제작기',
#  '2019 하반기 SK텔레콤 실시간 채용 설명회, T-Career Cast!',
#  '[SK텔레콤 5G] 상상을 현실로 바꾸는 VR의 모든 것(하)',
#  '[SK텔레콤] 초시대 AI 생활 NUGU Inside_B tv 편',
#  '[SK텔레콤] 초시대 AI 생활 NUGU Inside_T map 편',
#  '[SK텔레콤 5G] 상상을 현실로 바꾸는 VR의 모든 것(상)',
#  '[5G로 떠나는 0순위여행 | EP.8] 놓치면 후회하는 발리의 필수 코스 (by 여행에미치다)',
#  '[5G로 떠나는 0순위여행 | EP.7] 발리에서 꼭 찍어야 하는 인생샷 맛집! (by 여행에미치다)',
#  "[SK텔레콤 5G] 시속 210km 레이싱  '차세대 5G' 생중계에 도전하다",
#  '[T-WorX] SK텔레콤의 근무 체험형 인턴들은 무슨 일을 할까? 귀염뽀짝~ VLOG',
#  '[SK텔레콤] 김연아, 홍종현이 떴다! SKT 5GX Galaxy Note 10 | 10+ 런칭 세레모니',
#  '[5G로 떠나는 0순위여행 | EP.6] “여행에미치다”와 떠난 발리 이야기!',
#  '[동물 없는 동물원] 기술이 자연을 지킬 수 있다는 믿음으로 SK텔레콤이 먼저 나아갑니다.',
#  '[SK텔레콤 5G] 이렇게 놀라운 동물원은 태어나서 처음이야! Jump AR 동물원을 만나다 (feat.예콩이)',
#  '[5G로 떠나는 0순위여행 | EP.5] 나만의 0순위를, 우리 모두의 0순위를 찾아서!',
#  '[SK텔레콤 5G] SK텔레콤과 갤럭시노트10의 찰떡 만남 (feat.서울리안)',
#  '[SK텔레콤 5G] 초시대 올림픽공원 생활, 부스트 파크 올림픽 공원에서 자이언트캣과 인생샷을!',
#  "[SK텔레콤 5G] 임시정부 100주년 헌정공연, '5GX 라이브 오케스트라'로 세계를 잇다",
#  '[SK텔레콤 5G] 외국인들이 LoL Park에서 경험한 5GX 문화 충격!? (feat.단앤조엘)',
#  '[SK텔레콤 5G] 초시대 놀라운 생활, AR 자이언트캣 보러 부스트 파크 올림픽 공원으로!',
#  '[SK텔레콤 5G] 초시대 Note10+ BLUE, 결정적 할인',
#  '[SK텔레콤 5G] 초시대 Note10+ BLUE를 위한 결정적 콘텐츠',
#  "[SK텔레콤 5G] SKT 5GX로 LCK를 중계한다면? '나만의 5GX 중계' (feat. 클템, 저라뎃)",
#  '[5G로 떠나는 0순위여행 | EP.4] 멀티 대전으로 요새 던전을 공략하라! 팀 미션 승리팀은?',
#  '[5G로 떠나는 0순위여행 | EP.3] 어둠의 탐지기와 포트키, 해리포터 백배 즐기기!',
#  "SK텔레콤 X 갤럭시의 10번째 만남, '10년 케미' 인생샷 원정대 이야기",
#  '[SK텔레콤 5G] 초시대 Note10+ BLUE를 위한 결정적 선물',
#  '[SK텔레콤 5G] 초시대 Note10+ BLUE를 위한 결정적 멤버십',
#  '[SK텔레콤] 초시대 초캉스 생활 - Summer Festival Cool 비치로 놀러오세요!',
#  '[SK텔레콤 5G] 초시대 Note10+ BLUE, SKT 5GX와의 역대급 만남!',
#  '[SK텔레콤 5G] SKT 5GX 썸머페스티벌 해운대 이글루 (feat.판파니)',
#  '초시대 강남역 생활, 해리포터 게임한다면 지금 QR코드 찍어봐!',
#  '[SK텔레콤]내가 일하는 시간은 내가 정한다! 끄뇽의 초크초크한 브이로그',
#  '어촌 마을 미래의 로봇공학자들, 티움모바일에서 꿈의 씨앗을 틔우다 - T.um 모바일',
#  '초시대 롤파크 생활, SKT JUMP 앱으로 월챔 직관의 기회까지?!',
#  '[SK텔레콤 5G] 초시대 역대급 만남, Note하라!',
#  '초시대 홍대입구 생활, 완전 빠른 해리포터 게임 플레이를 원해? 홍대 입구로!',
#  '[SK텔레콤]초시대 해외 통신생활_초[로밍] T괌∙사이판 국내처럼_사이판 편',
#  '[SK텔레콤]초시대 해외 통신생활_초[로밍] T괌∙사이판 국내처럼_괌 편',
#  '[SK텔레콤] baro와 글로벌 멤버십으로 혜택 가득한 여름휴가 보내는 꿀팁! (feat.가전주부)',
#  '[SK텔레콤]해외여행의 필수품_초[로밍] baro _ 와이파이 편',
#  '[SK텔레콤]해외여행 필수품_초[로밍] baro _ 한달살기 편',
#  '[SK텔레콤]해외여행 필수품_초[로밍]생활 baro _ 고품질통화 편',
#  '[SK텔레콤]해외여행 필수품_초[로밍]생활 baro _ 무료통화(한국) 편',
#  '[SK텔레콤]해외여행의 필수품_초[로밍] baro _ 요금확인 편',
#  '[SK텔레콤]해외여행 필수품_초[로밍] baro _ 유심대비 편',
#  '[SK텔레콤]해외여행 필수품_초[로밍]생활 baro _ 무료통화(현지) 편',
#  '초시대 행복해지는 길, 초행길 이벤트에 참여해주세요',
#  '[SK텔레콤] 셰프 오스틴강과 NUGU의 만남',
#  '[5G로 떠나는 0순위여행 | EP.2] 서면에서 펼쳐진 마법 세계! 해리포터 마법사연합 AR 게임 대결',
#  '[5G로 떠나는 0순위여행 | EP.1] 엔조이커플과 10명의 마법사, 0순위를 찾아 부산으로 떠나다!',
#  '[SK텔레콤] 초시대 초캉스 생활, Summer Festival BIG 5!',
#  '초시대 동성로 생활, 해리포터 맛집이 여기였네..!',
#  '초시대 둔산 생활, 해리포터 발견물에 목마르다면? 둔산!',
#  '초시대 광화문 생활, 해리포터 주문에너지, 광화문 기운으로!',
#  '초시대 상무지구 생활, 지금 해리포터 핫플은 광주 상무!',
#  '초시대 서면 생활, 해리포터 게임 레벨업은 부산 서면에서!',
#  '[SK텔레콤]초시대 건강생활, T건강습관',
#  '[SK텔레콤]초시대 SNS 생활, Galaxy A40과 죵키가 만나다',
#  '[SK텔레콤]초시대 SNS 생활, Galaxy A40과 옐언니가 만나다',
#  '[SK텔레콤]초시대 SNS 생활, Galaxy A40과 김스테파니헤리가 만나다',
#  '[SK텔레콤]초시대 SNS 생활, Galaxy A40과 옐언니.죵키.김스테파니헤리가 만나다',
#  "[SK텔레콤 5G] SKT의 AR 기술을 파헤치다! '초크초크한 리뷰'",
#  "[SK텔레콤] 아시아 최초! '쥬라기 월드 특별전' 서울에 오다! SKT 고객은 20% 할인에 1GB 데이터까지",
#  '[SK텔레콤 5G] 초시대 놀라운 생활_해리포터 덕후라면, SKT 5GX 부스트파크로 오라!',
#  '[SK텔레콤 5G] 초시대 놀라운 생활_SKT 5GX 부스트파크, 오픈!',
#  '안전을 위협하는 테러 드론 막는다! - SKT 5G 가드 드론',
#  "[SK텔레콤] SKT의 모든 것을 리뷰하다! 초시대의 크리에이터가 전하는 '초크초크한 리뷰'",
#  '[SK텔레콤 5G] SKT 5GX 미디어 검색 기술 - 5G 시대 미디어, 원하는 장면만 골라보고, 필요한 정보는 바로 찾는다!',
#  '[SK텔레콤] 티움 모바일 아이들과 함께 꿈을 만들다!',
#  '[5G로 떠나는 0순위여행] 엔조이커플이 해리포터마법사연합 게임을 만난다면?? (코드명 : ‘0순위’)',
#  "[SK텔레콤] 외로운 어느날 '행복커뮤니티'가 찾아왔다",
#  '[SK텔레콤] 초시대 국프 생활_프로듀스X101 독점 VR 콘텐츠',
#  '[SK텔레콤] 국민 내비 Tmap이 쉬운 주차까지 책임집니다! Tmap 주차',
#  '[SK텔레콤 5G] 5G 시대 SKT와 농업이 만나면? 실시간 측위 기술(RTK) 탑재 자율주행 이앙기',
#  '[SK텔레콤] 초시대 음악 생활_나도 몰랐던 내 취향을 발견하다!',
#  '[SK텔레콤] 초시대 음악 생활_기술을 넘어 기회가 되는 시대',
#  "[SK텔레콤] 할머니들과 NUGU의 케미! '인공지능 돌봄 서비스'",
#  '[SK텔레콤 5G] 초시대 게임 생활_T1과 함께 알아 보기! VR 콘텐츠를 이용하는 올바른 자세',
#  '[SK텔레콤] 말로 하는 TV 생활, B tv (UHD)_NUGU 서비스 연동편!',
#  '[SK텔레콤] 말로 하는 TV쇼핑 생활, B tv (UHD)_SK stoa 이용편!',
#  '[SK텔레콤 5G] 초시대 게임 생활_멀티뷰_손흥민, T1 다 보고 있는거야?_45S',
#  '[SK텔레콤 5G] 초시대 게임 생활_멀티뷰_손흥민, T1 다 보고 있는거야?_30S',
#  '[SK텔레콤 5G] 엄마의 추억 속으로 들어가다',
#  '[SK텔레콤]초시대의 멤버십생활 T Day_6월 호',
#  '[SK텔레콤]초시대 금융생활_T high5 적금',
#  '[SK텔레콤] 텔레콤 아시아 어워드 2019 7관왕',
#  '[SK텔레콤] 초시대 0순위 여행, 2019 5GX 0순위 여행',
#  '[SK텔레콤 5G] SKT 5GX가 세상에 없던 중계 시스템을 제안하다 - 5GX 무선 생중계',
#  '[SK텔레콤] NUGU nemo(누구네모) 스마트홈',
#  '[SK텔레콤] 보이는 AI 스피커, NUGU nemo!',
#  '[SK텔레콤] NUGU nemo(누구네모) 놀이학습',
#  '[SK텔레콤 5G]SKT T1, 이보미, SK나이츠의 즐거운 쉬는 시간!',
#  '[SK텔레콤 5G]짧아도 확실한 프로들의 휴식법! (feat. T1, 이보미, SK나이츠)',
#  '[SK텔레콤] 나은이, 건후 스피커, NUGU nemo!',
#  '[SK텔레콤] SKT 5G로 듀얼스크린 3000만큼 즐기세요',
#  '[SK텔레콤] 말로 하는 TV 생활, B tv x NUGU!_음악감상 편',
#  '[SK텔레콤] 말로 하는 TV 생활, B tv x NUGU!_쇼핑 편',
#  '[SK텔레콤] 말로 하는 TV 생활, B tv x NUGU!_VOD검색 편',
#  '[SK텔레콤 5G] "프로듀스X101" SKT-5GX VR로 독점 공개',
#  '[SK텔레콤] NUGU nemo(누구네모) 검색 (NUGU백과/한영사전/국내프로야구)',
#  '[SK텔레콤] NUGU nemo(누구네모) 편리한 기능 (알람/Google캘린더/무드등)',
#  '[SK텔레콤 5G] 5G로 오면, [ ]가 온다?(feat.김태진)',
#  '[SK텔레콤 5G] 초시대의 초5G생활_5GX 가입했더니, VR팩이 공짜!',
#  '[SK텔레콤 5G] 초시대의 초5G생활_5GX 가입했더니, 경품이 와르르!',
#  '[SK텔레콤 5G] 초시대의 초5G생활_5GX 가입했더니, 50% 할인!',
#  '[SK텔레콤] NUGU nemo(누구네모) 두뇌게임',
#  '[SK텔레콤] T Day_연아 미공개 NG컷 대공개',
#  '[SK텔레콤] NUGU nemo(누구네모) 디바이스 연결하기',
#  '[SK텔레콤] NUGU nemo(누구네모) 생활정보(날씨/뉴스)',
#  '[SK텔레콤] NUGU nemo(누구네모) oksusu 키즈',
#  '[SK텔레콤] NUGU nemo(누구네모) 디지털액자',
#  '[SK텔레콤] NUGU의 새로운 통화 서비스, NUGU call(누구콜) 사용 방법',
#  '[SK텔레콤] NUGU nemo(누구네모) 언박싱',
#  '[SK텔레콤 5G] 옛 사진을 고화질로 바꾸는 방법 – 5G 슈퍼노바',
#  '[SK텔레콤]초시대의 멤버십생활 T Day_5월호',
#  '[SK텔레콤 5G] KOREAN 5G Tech Concert에 다녀오다',
#  '[SK텔레콤] NUGU(누구) 스마트홈',
#  '[SK텔레콤] NUGU(누구) 금융',
#  '[SK텔레콤] NUGU(누구) MY Q&A',
#  '[SK텔레콤] NUGU(누구) 누구앱 설치 & 연결',
#  '[SK텔레콤] NUGU(누구) 편리한 기능',
#  '[SK텔레콤] NUGU(누구) 음악/오디오',
#  '[SK텔레콤] NUGU(누구) 검색',
#  '[SK텔레콤] NUGU(누구) 생활정보',
#  '[SK텔레콤] NUGU(누구) 주문/쇼핑',
#  '[SK텔레콤] NUGU(누구) NUGU PLAY',
#  '[SK텔레콤 5G]하루 만에 초호화 5G 파리 여행을!? (feat.우와성)',
#  '[SK텔레콤]초시대 로밍생활_초[로밍] baro_효도 편',
#  '[SK텔레콤]초시대 로밍생활_초[로밍] baro_예약 편',
#  '[SK텔레콤]초시대 로밍생활_초[로밍] baro_친구 편',
#  '[SK텔레콤] NUGU nemo [누구네모] 출시영상',
#  '[SK텔레콤] 청각장애 택시기사님을 위한 ‘고요한택시 x T map 택시’',
#  '[SK텔레콤]초시대 로밍생활_초[로밍] baro_택배편',
#  '[SK텔레콤 5G] 초시대의 생중계 생활_30s',
#  '[SK텔레콤 5G] 초시대의 생중계 생활_45s',
#  '[SK텔레콤 5G] 초시대의 응원 생활_빠른중계_최강 곰',
#  '[SK텔레콤 5G] 초시대의 응원 생활_빠른중계_불꽃 독수리',
#  '[SK텔레콤 5G] 초시대의 응원 생활_넓게 자세히 보는 중계_부산 갈매기',
#  '[SK텔레콤 5G] 초시대의 응원 생활_넓게 자세히 보는 중계_최강 사자',
#  '[SK텔레콤 5G] 초시대의 응원 생활_넓게 자세히 보는 중계_영웅즈',
#  '[SK텔레콤 5G] 초시대의 응원 생활_데이터 걱정 없는 중계_공룡군단',
#  '[SK텔레콤 5G] 초시대의 응원 생활_데이터 걱정 없는 중계_연안 부두 비룡',
#  '[SK텔레콤 5G] 초시대의 응원 생활_데이터 걱정 없는 중계_최강 호랑이',
#  '[SK텔레콤] 행복커뮤니티- ICT 돌봄서비스 홍보영상',
#  '[SK텔레콤] 언제나 열려있는 미래형 매장 READY STORE',
#  '[SK텔레콤]초시대의 멤버십생활 T DAY_4월 창간호',
#  "[SK텔레콤] 'NUGU call'이 필요한 순간_ 연인 편",
#  "[SK텔레콤] 'NUGU call'이 필요한 순간_ 반려인 편",
#  "[SK텔레콤] 'NUGU call'이 필요한 순간_ 아이 편",
#  '[SK텔레콤 5G] 5GX 런칭 쇼케이스 현장을 가다!',
#  '[SK텔레콤 5G] 5G와 LCK의 만남! 새로운 게임이 시작된다!',
#  '[SK텔레콤 5G] 스마트 오피스를 본 외국인 신입사원의 반응은?',
#  '[SK텔레콤 5G] 초 시대, 현실에 5G AR 비룡이 출현!',
#  '[SK텔레콤 5G] KOREAN 5G Tech-Concert SK telecom 하이라이트',
#  '[SK텔레콤 5G] 초시대의 초5G생활_소셜VR 2편',
#  '[SK Telecom X MARVEL] 미니폰 어벤져스편',
#  '[SK텔레콤] LG G8 ThinQ 와 SKT의 특별한 서비스가 만났다',
#  '[SK텔레콤] 초시대의 병영생활 0 hero_연결편',
#  '[SK텔레콤] 초시대의 병영생활 0 hero_T map 택시+게임 편',
#  '[SK텔레콤] 초시대의 병영생활 0 hero_음악(FLO)+힐링카페 편',
#  '[SK텔레콤] 초시대의 병영생활 0 hero_연애+인강 편',
#  '[SKTelecom 5G]SK Telecom Uses 5G AR to Bring Fire-Breathing Dragon to Baseball Park',
#  '[SK텔레콤] 초시대의 로밍생활_baro 편',
#  '[SK텔레콤 5G] 2만2천명 야구 개막전 관중 눈길 사로잡은 5G AR 비룡',
#  '[SK텔레콤 5G] 인천 SK행복드림구장에 5G AR 비룡이 떴다',
#  '[SK텔레콤 5G] 초시대의 초5G생활_소셜VR 편',
#  '[SK텔레콤 5G] 초시대, 생활이 되다_초생활 편_30S',
#  '[SK텔레콤 5G] 초시대, 생활이 되다_초생활 편_60S',
#  '[SK텔레콤] T.um, iF 디자인 어워드 금상 수상',
#  '[SK텔레콤 5G] 초시대의 초5G 생활_속도 편_60S',
#  '[SK텔레콤 5G] 초시대의 초5G 생활_속도 편_30S',
#  '2019 SK텔레콤 상반기 실시간 유튜브 채용설명회, T-Career Live!']

# %%
all_temp = soup.find_all("span", class_="style-scope ytd-grid-video-renderer")

video_cnt = []
time_all = []
for idx, one in enumerate(all_temp):
    if idx%2==0:  # 짝수때의 값(조회수)
        video_cnt.append(one.text)
    else:         # 홀수때의 값 (시간)
        time_all.append(one.text)

# %%
video_cnt
# Out:
# ['조회수 932회',
#  '조회수 2천회',
#  '조회수 3.3만회',
#  '조회수 4.1만회',
#  '조회수 361회',
#  '조회수 4.5천회',
#  '조회수 395회',
#  '조회수 161회',
#  '조회수 6.9천회',
#  '조회수 7.1천회',
#  '조회수 4.9천회',
#  '조회수 5.9천회',
#  '조회수 8.3천회',
#  '조회수 2만회',
#  '조회수 142회',
#  '조회수 80회',
#  '조회수 146회',
#  '조회수 87만회',
#  '조회수 178만회',
#  '조회수 105회',
#  '조회수 57회',
#  '조회수 64회',
#  '조회수 800회',
#  '조회수 181회',
#  '조회수 106회',
#  '조회수 148회',
#  '조회수 3.8만회',
#  '조회수 17만회',
#  '조회수 17만회',
#  '조회수 18만회',
#  '조회수 19만회',
#  '조회수 2.8천회',
#  '조회수 2.7천회',
#  '조회수 1.1만회',
#  '조회수 2.8천회',
#  '조회수 46만회',
#  '조회수 6.3만회',
#  '조회수 6.6만회',
#  '조회수 19만회',
#  '조회수 4.6천회',
#  '조회수 13만회',
#  '조회수 830회',
#  '조회수 8.5만회',
#  '조회수 882회',
#  '조회수 1.1만회',
#  '조회수 9.5만회',
#  '조회수 907회',
#  '조회수 1.2천회',
#  '조회수 9.4만회',
#  '조회수 38만회',
#  '조회수 8만회',
#  '조회수 46만회',
#  '조회수 610만회',
#  '조회수 517만회',
#  '조회수 662만회',
#  '조회수 989회',
#  '조회수 894회',
#  '조회수 4천회',
#  '조회수 478회',
#  '조회수 7.5만회',
#  '조회수 1.3천회',
#  '조회수 8.5천회',
#  '조회수 434회',
#  '조회수 836회',
#  '조회수 217만회',
#  '조회수 645회',
#  '조회수 449만회',
#  '조회수 476만회',
#  '조회수 39만회',
#  '조회수 4만회',
#  '조회수 4.5만회',
#  '조회수 60만회',
#  '조회수 64만회',
#  '조회수 64만회',
#  '조회수 213만회',
#  '조회수 5만회',
#  '조회수 1.5천회',
#  '조회수 2천회',
#  '조회수 1.8천회',
#  '조회수 4.7만회',
#  '조회수 9.4만회',
#  '조회수 8.2만회',
#  '조회수 4.9천회',
#  '조회수 1.3천회',
#  '조회수 12만회',
#  '조회수 4.2만회',
#  '조회수 7.6만회',
#  '조회수 4만회',
#  '조회수 2.2천회',
#  '조회수 4.3천회',
#  '조회수 4.1만회',
#  '조회수 4.3만회',
#  '조회수 1천회',
#  '조회수 3.9만회',
#  '조회수 4.2만회',
#  '조회수 5.7만회',
#  '조회수 4.2만회',
#  '조회수 6.8만회',
#  '조회수 2.9만회',
#  '조회수 2천회',
#  '조회수 3만회',
#  '조회수 1.2만회',
#  '조회수 2.3천회',
#  '조회수 8.6만회',
#  '조회수 7.5만회',
#  '조회수 122만회',
#  '조회수 115만회',
#  '조회수 115만회',
#  '조회수 257만회',
#  '조회수 120만회',
#  '조회수 666만회',
#  '조회수 5.6만회',
#  '조회수 470만회',
#  '조회수 483만회',
#  '조회수 7.1만회',
#  '조회수 1.2천회',
#  '조회수 6만회',
#  '조회수 321만회',
#  '조회수 5.8만회',
#  '조회수 1018만회',
#  '조회수 1천회',
#  '조회수 1.5만회',
#  '조회수 1.8만회',
#  '조회수 6.2만회',
#  '조회수 1.4천회',
#  '조회수 34만회',
#  '조회수 7.2만회',
#  '조회수 1.4천회',
#  '조회수 3.8천회',
#  '조회수 1.5천회',
#  '조회수 1만회',
#  '조회수 3.3천회',
#  '조회수 2.8만회',
#  '조회수 299만회',
#  '조회수 3.7천회',
#  '조회수 1.8천회',
#  '조회수 2.2천회',
#  '조회수 3.8천회',
#  '조회수 3.7만회',
#  '조회수 8.9만회',
#  '조회수 3.6천회',
#  '조회수 5.5만회',
#  '조회수 4만회',
#  '조회수 5.8만회',
#  '조회수 2.3천회',
#  '조회수 62만회',
#  '조회수 3.5만회',
#  '조회수 714만회',
#  '조회수 25만회',
#  '조회수 2.8천회',
#  '조회수 4.5천회',
#  '조회수 888회',
#  '조회수 7.5천회',
#  '조회수 1.6천회',
#  '조회수 1.4만회',
#  '조회수 1.8만회',
#  '조회수 2만회',
#  '조회수 4.2천회',
#  '조회수 2.7만회',
#  '조회수 138만회',
#  '조회수 1.5만회',
#  '조회수 451만회',
#  '조회수 2.6천회',
#  '조회수 4.5천회',
#  '조회수 2.2천회',
#  '조회수 14만회',
#  '조회수 5.1천회',
#  '조회수 291만회',
#  '조회수 2만회',
#  '조회수 2.6천회',
#  '조회수 6천회',
#  '조회수 3.2천회',
#  '조회수 3만회',
#  '조회수 9.1천회',
#  '조회수 4.6천회',
#  '조회수 1018만회',
#  '조회수 199만회',
#  '조회수 2.2천회',
#  '조회수 1.9만회',
#  '조회수 4.4천회',
#  '조회수 290만회',
#  '조회수 1.5만회',
#  '조회수 91만회',
#  '조회수 164만회',
#  '조회수 1.3만회',
#  '조회수 1.8만회',
#  '조회수 709만회',
#  '조회수 541만회',
#  '조회수 1.7만회',
#  '조회수 6.2천회',
#  '조회수 1만회',
#  '조회수 3천회',
#  '조회수 2.6만회',
#  '조회수 1.5만회',
#  '조회수 7.5천회',
#  '조회수 2.9천회',
#  '조회수 5.3천회',
#  '조회수 5.4천회',
#  '조회수 5.3만회',
#  '조회수 1.5만회',
#  '조회수 86만회',
#  '조회수 345만회',
#  '조회수 520만회',
#  '조회수 181만회',
#  '조회수 3만회',
#  '조회수 1.8만회',
#  '조회수 86만회',
#  '조회수 110만회',
#  '조회수 122만회',
#  '조회수 2.2만회',
#  '조회수 1001만회',
#  '조회수 5천회',
#  '조회수 1.9만회',
#  '조회수 2천회',
#  '조회수 2.1만회',
#  '조회수 277만회',
#  '조회수 282만회',
#  '조회수 6.2천회',
#  '조회수 1.3만회',
#  '조회수 1.8만회',
#  '조회수 32만회',
#  '조회수 1018만회',
#  '조회수 1.9만회',
#  '조회수 1.4천회',
#  '조회수 1.6천회',
#  '조회수 2.2만회',
#  '조회수 1.8만회',
#  '조회수 1.3만회',
#  '조회수 1.1천회',
#  '조회수 158만회',
#  '조회수 2.5만회',
#  '조회수 1.6천회',
#  '조회수 2만회',
#  '조회수 91만회',
#  '조회수 3.8천회',
#  '조회수 3.2만회',
#  '조회수 88만회',
#  '조회수 357만회',
#  '조회수 297만회',
#  '조회수 7.5만회',
#  '조회수 1천회',
#  '조회수 1.6천회',
#  '조회수 732회',
#  '조회수 114만회',
#  '조회수 143만회',
#  '조회수 3.5천회',
#  '조회수 73만회',
#  '조회수 1.4만회',
#  '조회수 100만회',
#  '조회수 1.9만회',
#  '조회수 2.4천회',
#  '조회수 91만회',
#  '조회수 2.4천회',
#  '조회수 100만회',
#  '조회수 39만회',
#  '조회수 35만회',
#  '조회수 2.5만회',
#  '조회수 81만회',
#  '조회수 49만회',
#  '조회수 30만회',
#  '조회수 97만회',
#  '조회수 86만회',
#  '조회수 80만회',
#  '조회수 56만회',
#  '조회수 2.5만회',
#  '조회수 6.5천회',
#  '조회수 2.2천회',
#  '조회수 3.4천회',
#  '조회수 100만회',
#  '조회수 96만회',
#  '조회수 97만회',
#  '조회수 101만회',
#  '조회수 97만회',
#  '조회수 99만회',
#  '조회수 162만회',
#  '조회수 102만회',
#  '조회수 114만회',
#  '조회수 110만회',
#  '조회수 439만회',
#  '조회수 2.5만회',
#  '조회수 2.1천회',
#  '조회수 80만회',
#  '조회수 77만회',
#  '조회수 9.4천회',
#  '조회수 5천회',
#  '조회수 1.7만회',
#  '조회수 1.7천회',
#  '조회수 2.1천회',
#  '조회수 8.1천회',
#  '조회수 44만회',
#  '조회수 34만회',
#  '조회수 1.2만회',
#  '조회수 187만회',
#  '조회수 488만회',
#  '조회수 1016만회',
#  '조회수 9.7천회',
#  '조회수 2.7천회',
#  '조회수 1.6천회',
#  '조회수 611만회',
#  '조회수 8.6만회',
#  '조회수 5.2만회',
#  '조회수 157만회',
#  '조회수 318만회',
#  '조회수 3.8천회',
#  '조회수 405만회',
#  '조회수 8.4천회',
#  '조회수 1.5천회',
#  '조회수 2천회',
#  '조회수 922회',
#  '조회수 5.3만회',
#  '조회수 33만회',
#  '조회수 7.2천회',
#  '조회수 2.8천회',
#  '조회수 1.7천회',
#  '조회수 1.4천회',
#  '조회수 2천회',
#  '조회수 1.3만회',
#  '조회수 1천회',
#  '조회수 750회',
#  '조회수 3.9만회',
#  '조회수 107만회',
#  '조회수 91만회',
#  '조회수 84만회',
#  '조회수 1.8천회',
#  '조회수 1.6만회',
#  '조회수 1.9천회',
#  '조회수 745회',
#  '조회수 1.3천회',
#  '조회수 1.2천회',
#  '조회수 8.8천회',
#  '조회수 1.8천회',
#  '조회수 2만회',
#  '조회수 245만회',
#  '조회수 6.6천회',
#  '조회수 1.4천회',
#  '조회수 364회',
#  '조회수 385회',
#  '조회수 6.1천회',
#  '조회수 2.3천회',
#  '조회수 5.5천회',
#  '조회수 340회',
#  '조회수 429회',
#  '조회수 716회',
#  '조회수 473회',
#  '조회수 6.3만회',
#  '조회수 123만회',
#  '조회수 213만회',
#  '조회수 72만회',
#  '조회수 4.5천회',
#  '조회수 63만회',
#  '조회수 191만회',
#  '조회수 95만회',
#  '조회수 291만회',
#  '조회수 9.9천회',
#  '조회수 7.1만회',
#  '조회수 90만회',
#  '조회수 40만회',
#  '조회수 8.9만회',
#  '조회수 3.4만회',
#  '조회수 2.5만회',
#  '조회수 5.1만회',
#  '조회수 6.5천회',
#  '조회수 2.2천회',
#  '조회수 254만회',
#  '조회수 5.2천회',
#  '조회수 2.8천회',
#  '조회수 8.3천회',
#  '조회수 3.1천회',
#  '조회수 3.6천회',
#  '조회수 1만회',
#  '조회수 1.3만회',
#  '조회수 2.8천회',
#  '조회수 84만회',
#  '조회수 3.3천회',
#  '조회수 1.7천회',
#  '조회수 1.3만회',
#  '조회수 5.6천회',
#  '조회수 5.7천회',
#  '조회수 6.8천회',
#  '조회수 89만회',
#  '조회수 370만회',
#  '조회수 2.5만회',
#  '조회수 12만회',
#  '조회수 191만회',
#  '조회수 9.4천회',
#  '조회수 468만회',
#  '조회수 2.9천회',
#  '조회수 465만회',
#  '조회수 6.6천회',
#  '조회수 1.3만회']

# %%
time_all
# Out:
# ['6일 전',
#  '6일 전',
#  '1주 전',
#  '1주 전',
#  '2주 전',
#  '2주 전',
#  '2주 전',
#  '2주 전',
#  '2주 전',
#  '2주 전',
#  '2주 전',
#  '2주 전',
#  '2주 전',
#  '2주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '3주 전',
#  '4주 전',
#  '4주 전',
#  '4주 전',
#  '1개월 전',
#  '1개월 전',
#  '1개월 전',
#  '1개월 전',
#  '1개월 전',
#  '스트리밍 시간: 1개월 전',
#  '1개월 전',
#  '1개월 전',
#  '1개월 전',
#  '1개월 전',
#  '1개월 전',
#  '1개월 전',
#  '1개월 전',
#  '1개월 전',
#  '1개월 전',
#  '1개월 전',
#  '1개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '2개월 전',
#  '3개월 전',
#  '3개월 전',
#  '3개월 전',
#  '3개월 전',
#  '3개월 전',
#  '3개월 전',
#  '3개월 전',
#  '3개월 전',
#  '3개월 전',
#  '3개월 전',
#  '3개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '4개월 전',
#  '5개월 전',
#  '5개월 전',
#  '5개월 전',
#  '5개월 전',
#  '5개월 전',
#  '5개월 전',
#  '5개월 전',
#  '6개월 전',
#  '6개월 전',
#  '6개월 전',
#  '6개월 전',
#  '6개월 전',
#  '6개월 전',
#  '6개월 전',
#  '6개월 전',
#  '6개월 전',
#  '6개월 전',
#  '7개월 전',
#  '7개월 전',
#  '7개월 전',
#  '7개월 전',
#  '7개월 전',
#  '8개월 전',
#  '8개월 전',
#  '8개월 전',
#  '8개월 전',
#  '8개월 전',
#  '8개월 전',
#  '9개월 전',
#  '9개월 전',
#  '9개월 전',
#  '9개월 전',
#  '9개월 전',
#  '9개월 전',
#  '9개월 전',
#  '10개월 전',
#  '10개월 전',
#  '10개월 전',
#  '10개월 전',
#  '10개월 전',
#  '10개월 전',
#  '10개월 전',
#  '10개월 전',
#  '10개월 전',
#  '10개월 전',
#  '10개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '11개월 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전',
#  '1년 전']

# %%
print(len(title), len(video_cnt), len(time_all))
# Out:
# 390 390 390

# %%
import pandas as pd

dat = {"영화제목":title, "조회수":video_cnt, "시간":time_all}
all_data = pd.DataFrame(dat)
all_data
# Out:
#                                                   영화제목        조회수    시간
# 0                                    긴급 재난 문자 수신 설정 방법   조회수 932회  6일 전
# 1    [SK텔레콤 5G] 누구든 보고 어디서든 느낄 수 있도록 ‘창덕ARirang at ...    조회수 2천회  6일 전
# 2                            행복을 드리는 SK텔레콤 고객센터 김은혜입니다  조회수 3.3만회  1주 전
# 3               [SKT x 최태성] 언택트 시대 & 4차 산업혁명, 기업의 미래는?  조회수 4.1만회  1주 전
# 4                            T전화 활용하기_T114 업체 정보 등록 방법   조회수 361회  2주 전
# ..                                                 ...        ...   ...
# 385                   [SK텔레콤 5G] 초시대, 생활이 되다_초생활 편_60S  조회수 468만회  1년 전
# 386                     [SK텔레콤] T.um, iF 디자인 어워드 금상 수상  조회수 2.9천회  1년 전
# 387                    [SK텔레콤 5G] 초시대의 초5G 생활_속도 편_60S  조회수 465만회  1년 전
# 388                    [SK텔레콤 5G] 초시대의 초5G 생활_속도 편_30S  조회수 6.6천회  1년 전
# 389       2019 SK텔레콤 상반기 실시간 유튜브 채용설명회, T-Career Live!  조회수 1.3만회  1년 전
#
# [390 rows x 3 columns]

# %% [markdown]
# ### 링크 가져오기

# %%
link_one = soup.find_all("a", class_="yt-simple-endpoint inline-block style-scope ytd-thumbnail")
print(len(link_one))
link_one[150].find("img", class_="style-scope yt-img-shadow")
# Out:
# 391
# <img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/nBUCn0R6RBM/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLA_0LIGWFj9YKGPZhgjVFuP70Pr_A" width="210"/>

# %%
link_one = soup.find_all("a", class_="yt-simple-endpoint inline-block style-scope ytd-thumbnail")
print(len(link_one))

for one in link_one:
    tmp = one.find("img", class_="style-scope yt-img-shadow")
    print(tmp.attrs)
    print(tmp.attrs.src)
# Out:
# 181
# {'id': 'img', 'class': ['style-scope', 'yt-img-shadow'], 'alt': '', 'width': '210', 'src': 'https://i.ytimg.com/vi/6yjCu6EHyGY/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLCaZJQmELhL_rFlfRIG9wJIW1q8eQ'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-d315144a6041> in <module>
#       5     tmp = one.find("img", class_="style-scope yt-img-shadow")
#       6     print(tmp.attrs)
# ----> 7     print(tmp.attrs.src)
#
# AttributeError: 'dict' object has no attribute 'src'

# %%
### 파일로 만들기
all_data.to_excel("sk_youtube.xlsx", index=False)
